# %%
# %pip install diffusers transformers
# Out:
# Requirement already satisfied: diffusers in c:\users\arya6\.conda\envs\python39\lib\site-packages (0.29.2)
# Requirement already satisfied: transformers in c:\users\arya6\.conda\envs\python39\lib\site-packages (4.42.3)
# Requirement already satisfied: importlib-metadata in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (7.0.1)
# Requirement already satisfied: filelock in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (3.14.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (0.23.3)
# Requirement already satisfied: numpy in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (0.4.3)
# Requirement already satisfied: Pillow in c:\users\arya6\.conda\envs\python39\lib\site-packages (from diffusers) (10.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\arya6\appdata\roaming\python\python39\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\arya6\.conda\envs\python39\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from requests->diffusers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arya6\.conda\envs\python39\lib\site-packages (from requests->diffusers) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
import torch
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
image_model = "dreamlike-art/dreamlike-diffusion-1.0"

pipeline = StableDiffusionPipeline.from_pretrained(image_model, torch_dtype=torch.float16)
pipeline = pipeline.to("cuda")
# Out:
# model_index.json:   0%|          | 0.00/511 [00:00<?, ?B/s]
# c:\Users\arya6\.conda\envs\python39\lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\arya6\.cache\huggingface\hub\models--dreamlike-art--dreamlike-diffusion-1.0. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/807 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/518 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/901 [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
prompt = """ mass effect andromeda type astronaut with proper galaxy background the astronaut is male """

# %%
image = pipeline(prompt).images[0]
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images = pipeline(prompt,num_inference_steps=100, height = 512, width = 1024).images #more steps more better image accuracy since more times the model is trained
images[0]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x512>
